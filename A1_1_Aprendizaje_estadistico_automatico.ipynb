# %% [markdown]
# # A1.1 Aprendizaje Estadístico-Automático
#
# **Autor:** Ricardo Arath Sanchez Aguirre
#
# **Materia:** SC3314 – Inteligencia Artificial
# **Universidad:** Universidad de Monterrey
# **Profesor:** Dr. Antonio Martínez Torteya
#
# ---

# %% [markdown]
# ## Introducción
#
# En este documento se exploran los conceptos fundamentales del aprendizaje estadístico y automático (Machine Learning), incluyendo:
#
# - Conceptos básicos de aprendizaje automático
# - Tipos de aprendizaje: supervisado, no supervisado y por refuerzo
# - Modelos estadísticos
# - Evaluación de modelos

# %% [markdown]
# ## 1. Conceptos Fundamentales
#
# ### 1.1 ¿Qué es el Aprendizaje Automático?
#
# [Añadir contenido del PDF aquí]

# %% [markdown]
# ### 1.2 Aprendizaje Supervisado vs No Supervisado
#
# [Añadir contenido del PDF aquí]

# %% [markdown]
# ## 2. Modelos Estadísticos
#
# ### 2.1 Regresión
#
# [Añadir contenido del PDF aquí]

# %%
# Ejemplo de código
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Tu código aquí

# %% [markdown]
# ### 2.2 Clasificación
#
# [Añadir contenido del PDF aquí]

# %% [markdown]
# ## 3. Evaluación de Modelos
#
# ### 3.1 Métricas de Desempeño
#
# [Añadir contenido del PDF aquí]

# %% [markdown]
# ### 3.2 Validación Cruzada
#
# [Añadir contenido del PDF aquí]

# %% [markdown]
# ## 4. Overfitting y Underfitting
#
# [Añadir contenido del PDF aquí]

# %% [markdown]
# ## Conclusiones
#
# [Añadir conclusiones del PDF aquí]

# %% [markdown]
# ## Referencias
#
# [Añadir referencias aquí]
